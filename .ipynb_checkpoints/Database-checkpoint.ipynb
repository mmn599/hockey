# %% [markdown]
# ## Database thoughts
#
# Here's what we want to be able to easily get: <br>
# (1) List of players competing in game <br>
# (2) List of games a player has played in <br>
# (3) List of games based on date range <br>
# (4) All stats for each game <br>
# (5) Summation of stats for a particular player's games over a particular date range <br>
#
# Tables <br>
# (1) GAME_OVERALL<br>
# (2) SKATER_GAME<br>
# (3) GOALIE_GAME<br>
# (4) PLAYER<br>
# (5) TEAM
#
#
# TODO<br>
# (1) Make sure engines are getting cleaned up<br>
# (2) Better table schema and unique keys and shit<br>

# %%
### Constants ###
DIR_GAMES = "./data/Games/"
FILE_GAMES = DIR_GAMES + "2015Games.csv"
URL_Games_20152016 = "http://www.hockey-reference.com/leagues/NHL_2016_games.html"
DB_NAME = "test.db"

build_games_csv(URL_Games_20152016, FILE_GAMES)
build_database(DB_NAME, FILE_GAMES)
view_database(DB_NAME, TABLE_GAMEOVERALL)
# Out:
#      index                                                URL        Date  \
# 0        0  http://www.hockey-reference.com/boxscores/2015...  2015-10-07
# 1        1  http://www.hockey-reference.com/boxscores/2015...  2015-10-07
# 2        2  http://www.hockey-reference.com/boxscores/2015...  2015-10-07
# 3        3  http://www.hockey-reference.com/boxscores/2015...  2015-10-07
# 4        4  http://www.hockey-reference.com/boxscores/2015...  2015-10-08
# 5        5  http://www.hockey-reference.com/boxscores/2015...  2015-10-08
# 6        6  http://www.hockey-reference.com/boxscores/2015...  2015-10-08
# 7        7  http://www.hockey-reference.com/boxscores/2015...  2015-10-08
# 8        8  http://www.hockey-reference.com/boxscores/2015...  2015-10-08
# 9        9  http://www.hockey-reference.com/boxscores/2015...  2015-10-08
# 10      10  http://www.hockey-reference.com/boxscores/2015...  2015-10-08
# 11      11  http://www.hockey-reference.com/boxscores/2015...  2015-10-09
# 12      12  http://www.hockey-reference.com/boxscores/2015...  2015-10-09
# 13      13  http://www.hockey-reference.com/boxscores/2015...  2015-10-09
# 14      14  http://www.hockey-reference.com/boxscores/2015...  2015-10-09
# 15      15  http://www.hockey-reference.com/boxscores/2015...  2015-10-09
# 16      16  http://www.hockey-reference.com/boxscores/2015...  2015-10-10
# 17      17  http://www.hockey-reference.com/boxscores/2015...  2015-10-10
# 18      18  http://www.hockey-reference.com/boxscores/2015...  2015-10-10
# 19      19  http://www.hockey-reference.com/boxscores/2015...  2015-10-10
# 20      20  http://www.hockey-reference.com/boxscores/2015...  2015-10-10
# 21      21  http://www.hockey-reference.com/boxscores/2015...  2015-10-10
# 22      22  http://www.hockey-reference.com/boxscores/2015...  2015-10-10
# 23      23  http://www.hockey-reference.com/boxscores/2015...  2015-10-10
# 24      24  http://www.hockey-reference.com/boxscores/2015...  2015-10-10
# 25      25  http://www.hockey-reference.com/boxscores/2015...  2015-10-10
# 26      26  http://www.hockey-reference.com/boxscores/2015...  2015-10-10
# 27      27  http://www.hockey-reference.com/boxscores/2015...  2015-10-10
# 28      28  http://www.hockey-reference.com/boxscores/2015...  2015-10-10
# 29      29  http://www.hockey-reference.com/boxscores/2015...  2015-10-10
# ...    ...                                                ...         ...
# 1200  1200  http://www.hockey-reference.com/boxscores/2016...  2016-04-07
# 1201  1201  http://www.hockey-reference.com/boxscores/2016...  2016-04-07
# 1202  1202  http://www.hockey-reference.com/boxscores/2016...  2016-04-07
# 1203  1203  http://www.hockey-reference.com/boxscores/2016...  2016-04-07
# 1204  1204  http://www.hockey-reference.com/boxscores/2016...  2016-04-07
# 1205  1205  http://www.hockey-reference.com/boxscores/2016...  2016-04-07
# 1206  1206  http://www.hockey-reference.com/boxscores/2016...  2016-04-07
# 1207  1207  http://www.hockey-reference.com/boxscores/2016...  2016-04-07
# 1208  1208  http://www.hockey-reference.com/boxscores/2016...  2016-04-07
# 1209  1209  http://www.hockey-reference.com/boxscores/2016...  2016-04-07
# 1210  1210  http://www.hockey-reference.com/boxscores/2016...  2016-04-07
# 1211  1211  http://www.hockey-reference.com/boxscores/2016...  2016-04-07
# 1212  1212  http://www.hockey-reference.com/boxscores/2016...  2016-04-08
# 1213  1213  http://www.hockey-reference.com/boxscores/2016...  2016-04-09
# 1214  1214  http://www.hockey-reference.com/boxscores/2016...  2016-04-09
# 1215  1215  http://www.hockey-reference.com/boxscores/2016...  2016-04-09
# 1216  1216  http://www.hockey-reference.com/boxscores/2016...  2016-04-09
# 1217  1217  http://www.hockey-reference.com/boxscores/2016...  2016-04-09
# 1218  1218  http://www.hockey-reference.com/boxscores/2016...  2016-04-09
# 1219  1219  http://www.hockey-reference.com/boxscores/2016...  2016-04-09
# 1220  1220  http://www.hockey-reference.com/boxscores/2016...  2016-04-09
# 1221  1221  http://www.hockey-reference.com/boxscores/2016...  2016-04-09
# 1222  1222  http://www.hockey-reference.com/boxscores/2016...  2016-04-09
# 1223  1223  http://www.hockey-reference.com/boxscores/2016...  2016-04-09
# 1224  1224  http://www.hockey-reference.com/boxscores/2016...  2016-04-09
# 1225  1225  http://www.hockey-reference.com/boxscores/2016...  2016-04-09
# 1226  1226  http://www.hockey-reference.com/boxscores/2016...  2016-04-09
# 1227  1227  http://www.hockey-reference.com/boxscores/2016...  2016-04-09
# 1228  1228  http://www.hockey-reference.com/boxscores/2016...  2016-04-10
# 1229  1229  http://www.hockey-reference.com/boxscores/2016...  2016-04-10
#
#                     Visitor  G                   Home  G.1     OT    Att.  \
# 0         Vancouver Canucks  1         Calgary Flames    1  False  19,289
# 1          New York Rangers  2     Chicago Blackhawks    2  False  22,104
# 2           San Jose Sharks  1      Los Angeles Kings    1  False  18,230
# 3        Montreal Canadiens  1    Toronto Maple Leafs    1  False  19,241
# 4             Winnipeg Jets  2          Boston Bruins    2  False  17,565
# 5           Ottawa Senators  1         Buffalo Sabres    1  False  19,070
HOME = "Home"
AWAY = "Away"
TABLE_GAMEOVERALL = "GAME_STATS"
TABLE_PLAYERGAME = "SKATER_GAME"
TABLE_GOALIEGAME = "GOALIE_GAME"
TABLE_PLAYER = "PLAYER"
TABLE_TEAM = "TEAM"

def get_playerstats_files(gamename):
    team1 = GAMESDIR + gamename + '_' + PLAYER_STATS_FILE + HOME + '.csv'
    team2 = GAMESDIR + gamename + '_' + PLAYER_STATS_FILE + AWAY + '.csv'
    return team1, team2

def gamefile_to_gamename(gamefile):
    gamename = str(gamefile)
    gamename = gamename.replace('.csv', '')
    gamename = gamename.replace("./Games\\", '')
    return gamename

def append_columns(game, team1, team2):
    d_game['GameName'] = gamename
    d_team1['GameName'] = gamename
    d_team2['GameName'] = gamename
    d_team1['Result'] = TEAM1
    
def get_gamename(season, game):
    return str(season) + "_" + str(game[0])

def build_database(db_name, csv_games):    
    engine = get_engine(db_name)
    d_games = pd.read_csv(csv_games)
    gamenames = []
    dates = []
    # TODO: get rid of this for loop
    for game in d_games.iterrows():
        gamename = get_gamename(2015, game)
        gamenames.append(gamename)
        dt = datetime.datetime.strptime(game[1][1], '%Y-%m-%d')
        date = int(dt.timestamp())
        dates.append(date)
    d_games['DateTimestamp'] = dates
    d_games['GameName'] = gamenames
    d_games = d_games.rename(index=str, columns={"Unnamed: 6":"OT"})
    d_games = d_games.drop('Notes', 1)
    d_games.OT = d_games.OT=="OT"
    d_games.to_sql(TABLE_GAMEOVERALL, engine, if_exists='replace')

# %% [markdown]
# ## Database lookup functions

# %%
def get_engine(db_name):
    return sqlalchemy.create_engine('sqlite:///' + db_name)

def view_database(db_name, table):
    engine = get_engine(db_name)
    d_db = pd.read_sql_table(table, engine)
    ICD.display(d_db)
    
def get_game_by_gamename(engine, gamename):
    sql_query = 'SELECT * from ' + TABLE_GAMEOVERALL + ' WHERE GameName == \'' + str(gamename) + '\';'
    games = pd.read_sql_query(sql_query, engine)
    return games

def get_games_in_daterange(engine, date1, date2):
    date1 = int(date1.timestamp())
    date2 = int(date2.timestamp())
    sql_query = 'SELECT * from ' + TABLE_GAMEOVERALL + ' WHERE DateTimestamp >= ' + str(date1) + ' AND ' + 'DateTimestamp <= ' + str(date2)
    games = pd.read_sql_query(sql_query, engine)
    return games

# %% [markdown]
# ## Web scraping functions

# %%
import urllib.request
import pandas as pd
from bs4 import BeautifulSoup
import csv

def build_games_csv(url, file):
    soup = BeautifulSoup(urllib.request.urlopen(url).read(), "lxml")

    tablehead = soup.find('thead')
    tablebody = soup.find('tbody')

    headers = [header.text for header in tablehead.find('tr').find_all('th')]
    headers.insert(0, "URL")
    rows = []

    for row in tablebody.find_all('tr'):
        cells = [cell.text for cell in row.find_all(['th','td'])]
        url = 'http://www.hockey-reference.com' + row.find('th').find('a')['href']
        cells.insert(0, url)
        rows.append(cells)

    with open(file, 'w') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=headers)
        writer.writeheader()
        for row in rows:
            row_dict = {}
            for i,cell in enumerate(row):
                row_dict[headers[i]] = cell
            writer.writerow(row_dict)
    
def get_playergame_csvname(gamename, home, skater):
    team = "HOME" if home else "AWAY"
    player = "SKATER" if skater else "GOALIE"
    return gamename + "_" + team + "_" + skater + ".csv"

def skater_game_table_to_csv(table, game, home):
    print(game)
#     print(table)
            
def build_playergame_csvs(gamename, url):
    soup = BeautifulSoup(urllib.request.urlopen(url).read(), "lxml")
    tables = soup.find_all('table')
    table_skaters_away = tables[2]
    table_goalies_away = tables[3]
    table_skaters_home = tables[4]
    table_goalies_home = tables[5]
    game = get_game_by_gamename(gamename)
    skater_game_table_to_csv(table_skaters_away, game, False)

build_playergame_csvs("Game1", "http://www.hockey-reference.com/boxscores/201510070CGY.html")
# Out:
# Empty DataFrame
# Columns: [index, URL, Date, Visitor, G, Home, 1, OT, , LOG, DateTimestamp, GameName]
# Index: []

# %% [markdown]
# ## Temporary

# %%
# get_games_csv(URL_Games_20152016)
# build_database(DB_NAME, FILE_GAMES)
# view_database(DB_NAME, TABLE_GAMEOVERALL)

build_playergame_csv("Game1", "http://www.hockey-reference.com/boxscores/201510070CGY.html")
# Out:
# <table class="sortable stats_table" data-cols-to-freeze="2" id="CGY_goalies"><caption>Goalies Table</caption>
# <colgroup><col></col><col></col><col></col><col></col><col></col><col></col><col></col><col></col><col></col><col></col></colgroup>
# <thead>
# <tr class="over_header">
# <th aria-label="" class=" over_header " colspan="3" data-stat=""></th>
# <th aria-label="" class=" over_header center" colspan="5" data-stat="header_goalies">Goalie Stats</th><th></th><th></th>
# </tr>
# <tr>
# <th aria-label="Rank" class="ranker tooltip sort_default_asc show_partial_when_sorting center" data-stat="ranker" data-tip="Rank" scope="col">Rk</th>
# <th aria-label="Player" class=" tooltip sort_default_asc left" data-stat="player" scope="col">Player</th>
# <th aria-label="Decision" class=" tooltip sort_default_asc center" data-stat="decision" data-tip="Decision" scope="col">DEC</th>
# <th aria-label="Goals Against" class=" tooltip center" data-over-header="Goalie Stats" data-stat="goals_against" data-tip="Goals Against" scope="col">GA</th>
# <th aria-label="Shots Against" class=" tooltip center" data-over-header="Goalie Stats" data-stat="shots_against" data-tip="Shots Against" scope="col">SA</th>
# <th aria-label="Saves" class=" tooltip center" data-over-header="Goalie Stats" data-stat="saves" data-tip="Saves" scope="col">SV</th>
# <th aria-label="Save Percentage" class=" tooltip center" data-over-header="Goalie Stats" data-stat="save_pct" data-tip="Save Percentage" scope="col">SV%</th>
# <th aria-label="Shutouts" class=" tooltip center" data-over-header="Goalie Stats" data-stat="shutouts" data-tip="Shutouts" scope="col">SO</th>
# <th aria-label="Penalties in Minutes" class=" tooltip center" data-stat="pen_min" data-tip="Penalties in Minutes" scope="col">PIM</th>
# <th aria-label="Time on Ice" class=" tooltip center" data-over-header="Ice Time" data-stat="time_on_ice" data-tip="Time on Ice (in minutes)" scope="col">TOI</th>
# </tr>
# </thead>
# <tbody><tr><th class="right " csk="1" data-stat="ranker" scope="row">1</th><td class="left " csk="Ramo,Karri" data-append-csv="ramoka01" data-stat="player"><a href="/players/r/ramoka01.html">Karri Ramo</a></td><td class="center " data-stat="decision">L</td><td class="right " data-stat="goals_against">5</td><td class="right " data-stat="shots_against">44</td><td class="right " data-stat="saves">39</td><td class="right " data-stat="save_pct">.886</td><td class="right " data-stat="shutouts">0</td><td class="right " data-stat="pen_min">0</td><td class="right " csk="3600" data-stat="time_on_ice">60:00</td></tr>
# </tbody></table>
