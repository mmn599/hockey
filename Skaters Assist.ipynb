# %% [markdown]
# ### Get the data

# %%
from sklearn.externals import joblib
from IPython.core import display as ICD

data = joblib.load('2015Skaters.p')
outputs = [x for x in data.columns.values if 'O_' in x]
ICD.display(data)
# Out:
#        GameNum   GameName             Player  DateTimestamp   Num  GNum  \
# 22139    615.0   2015_615      Patrick Sharp   1.452319e+09  43.0  33.0
# 22140    615.0   2015_615       Jason Spezza   1.452319e+09  43.0  33.0
# 22141    615.0   2015_615       Tyler Seguin   1.452319e+09  43.0  33.0
# 22142    615.0   2015_615       Jonas Brodin   1.452319e+09  39.0  28.0
# 22143    615.0   2015_615        Ryan Carter   1.452319e+09  37.0  28.0
# 22144    615.0   2015_615     Alex Goligoski   1.452319e+09  43.0  33.0
# 22145    615.0   2015_615    Antoine Roussel   1.452319e+09  41.0  33.0
# 22146    615.0   2015_615    Colton Sceviour   1.452319e+09  40.0  33.0
# 22147    615.0   2015_615       Johnny Oduya   1.452319e+09  43.0  33.0
# 22148    615.0   2015_615  Valeri Nichushkin   1.452319e+09  40.0  33.0
# 22149    615.0   2015_615     John Klingberg   1.452319e+09  43.0  33.0
# 22150    615.0   2015_615    Jyrki Jokipakka   1.452319e+09  32.0  33.0
# ...

# %% [markdown]
# ### Clean the data
#
# Remove records with small Num (Num is the number of previous games the target player has played in this season). <br>
# Remove the non numerical columns.

# %%
num_threshold = 20
gnum_threshold = 10
data = data[data.Num >= num_threshold]
data = data[data.GNum >= gnum_threshold]
print(data['Num'].describe())
print(data['GNum'].describe())
# Out:
# count    18721.000000
# mean        52.702633
# std         14.077763
# min         20.000000
# 25%         43.000000
# 50%         53.000000
# 75%         63.000000
# max         83.000000
# Name: Num, dtype: float64
# count    18721.000000
# mean        34.103467
# std         13.860802
# min         10.000000
# 25%         23.000000
# 50%         34.000000
# 75%         45.000000
# max         67.000000
# Name: GNum, dtype: float64

# %%
data = data.fillna(0)

# %%
dropcols = ['GameNum', 'GameName', 'Player', 'DateTimestamp', 'Num']
cleandata = data.drop(dropcols, 1)
print(cleandata.columns.values)
# Out:
# ['GNum' 'O_Goals' 'O_Assists' 'O_Blocks' 'O_Shorthanded' 'O_Shots'
#  'TS_Goals' 'TS_Assists' 'TS_PlusMinus' 'TS_SoG' 'TS_Shot%' 'TS_ATOI'
#  'TS_iCF' 'TS_SATF' 'TS_SATA' 'TS_ZSO' 'TS_HIT' 'TS_BLK' 'TM_Goals'
#  'Opp_GA' 'Opp_SA' 'Opp_SV%']

# %% [markdown]
# # Assists

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve
from sklearn.linear_model import LinearRegression
from matplotlib import pyplot as plt
from sklearn.preprocessing import StandardScaler 
from sklearn.ensemble import AdaBoostClassifier
# %matplotlib inline

def visualize(clf, X_test, y_test):
    y_prob = clf.predict_proba(X_test)
    y_pred = clf.predict(X_test)
    fpr, tpr, _ = roc_curve(y, y_prob[:,1])
    plt.plot(fpr, tpr)
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC')
    plt.show()
    cm = confusion_matrix(y_test, y_pred)
    print(cm)

# %%
X_goals = cleandata.drop(outputs, axis=1)
y_goals = cleandata['O_Assists']
y_goals[y_goals > 0] = 1
# X_goals = cleandata[['TS_Shot%','TS_SoG', 'TS_ATOI', 'TS_Goals']]

# %%
X = X_goals.as_matrix()
y = y_goals.as_matrix()
scaler = StandardScaler()  
scaler.fit(X)  
X = scaler.transform(X)

# %%
clf = MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(20, 20), random_state=1)
clf.fit(X, y)
visualize(clf, X, y)
# Out:
# [[14072   423]
#  [ 3632   594]]

# %%
clf = AdaBoostClassifier(n_estimators=100)

# %%
from sklearn.decomposition import PCA 
from matplotlib import pyplot as plt

pca = PCA(5) 

component_scores = pca.fit_transform(cleandata)
print(component_scores)
# here we transform to Data Frame, # only so that we can add the country names as a row index
component_scores = pd.DataFrame(component_scores, index=df.index.values)
plt.scatter(component_scores[0],component_scores[1]) 
plt.xlabel('Largest component') 
plt.ylabel('Second component') 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-57577a8bb33a> in <module>()
#       6 component_scores = pca.fit_transform(cleandata)
#       7 # here we transform to Data Frame, # only so that we can add the country names as a row index
# ----> 8 component_scores = pd.DataFrame(component_scores, index=df.index.values)
#       9 plt.scatter(component_scores[0],component_scores[1])
#      10 plt.xlabel('Largest component')
#
# NameError: name 'pd' is not defined

# %%
from sklearn.decomposition import PCA 
from matplotlib import pyplot as plt

pca = PCA(5) 

component_scores = pca.fit_transform(cleandata)
print(component_scores)
# Out:
# [[  66.57961214   -1.0126417    -5.46547776   -6.26751501   -0.73154535]
#  [   6.60545806   -1.05930954   -6.89140039   -6.53300677   -0.49687507]
#  [ 158.69995648   -0.88678103  -12.90335577   -7.00145203   -0.5649268 ]
#  ...,
#  [-312.07356468  -13.56493262   -0.68033911    2.1816156     3.30083246]
#  [ 283.06344027    8.13271236  -11.5964529     6.99330263    2.78384859]
#  [-295.94920203  -13.56789917    1.27142187   -1.84464513    3.27860999]]

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import (train_test_split,KFold)
from sklearn.metrics import mean_squared_error
from sklearn.neural_network import MLPRegressor
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
# %matplotlib inline

X_assists = cleandata.drop(outputs, axis=1)
y_assists = cleandata['O_Assists']
y_assists[y_assists > 0] = 1

X_train, X_test, y_train, y_test = train_test_split(X_assists,y_assists,test_size = 0.33, random_state=42)

param_hidden_layers = [(5,)]

n_folds = 5
k_folds = KFold(n_splits=n_folds)
lrate = 0.001

for param_hidden in param_hidden_layers:
    aRMSE = 0
    for train_idx, test_idx in k_folds.split(X_train):
        regMLP = MLPRegressor(activation = 'tanh',
                              solver = 'sgd',
                              learning_rate='constant',
                              random_state=42,
                              batch_size=40,
                              learning_rate_init = lrate,
                              hidden_layer_sizes = param_hidden)
        stdScaler = StandardScaler()
        xTrain = stdScaler.fit_transform(X_train.iloc[train_idx,:])
        yTrain = y_train.iloc[train_idx]
            
        regMLP.fit(xTrain,yTrain)
        #aRMSE += np.sqrt(mean_squared_error(y_train.iloc[test_idx], regMLP.predict(stdScaler.transform(X_train.iloc[test_idx,:]))))/n_folds
        print(regMLP.score(xTrain, yTrain))
    
    #print('<hidden layer: {}>\n Average RMSE (CV): {}\n'.format(param_hidden,aRMSE))
# Out:
# 0.0525171010472
# 0.0493780108158
# 0.0523787120795
# 0.0485929325808
# 0.0536056088982
